# %% [markdown]
# # Unstructured Data Analytics HW1
#
# Name: Solutions
#
# Andrew ID: N/A
#
# Collaborators (if none, say "none"; do *not* leave this blank): none
#
# Reminder: you should not be sharing code.

# %% [markdown]
# **Warning: make sure your compute environment is set up first.** This homework assignment assumes that you have already installed Anaconda Python 3 and spaCy. Instructions for installing these are part of the tutorial [here](https://www.andrew.cmu.edu/user/georgech/95-865/Anaconda,%20Jupyter,%20and%20spaCy%20setup%20tutorial.pdf).

# %% [markdown]
# ### Instructions
# 1. Fill in your name, Andrew ID, and collaborators above.
# 2. Fill in the code/text blocks to answer each question.
# 3. Do *not* change any of the existing code provided.
# 4. Run the entire notebook *before* submitting it on Canvas to make sure that the code actually runs without errors. (**Important**: Any code cells that you have entered code for but did not actually execute will be disregarded, so please be sure to actually run your code first and make sure it runs without errors! We may re-run a subset of your code for grading purposes.)
# 5. Be careful about where you save data for use with this Jupyter notebook (more details on this later).

# %% [markdown]
# ### [Problem 1] Basic Text Analysis [45 pts]
#
# This problem involves a mix of Python review (loops, conditionals, counters/dictionaries, sorting) and learning to work with a sizable collection of text data.
#
# You will be looking at a phenomenon of "natural languages" (i.e., human languages, such as English) called *Zipf's law*, which relates how frequently a word occurs in a language to its "rank" (the word with rank 1 is the most frequently occurring word, the word with rank 2 is the second most frequently occurring word, etc). Roughly speaking, the word with rank 1 appears twice as likely as the word with rank 2, and the three times as likely as the word with rank 3, and so forth. (Some details on Zipf's law can be found on [Wikipedia](https://en.wikipedia.org/wiki/Zipf%27s_law).) In this problem, you are going to check whether Zipf's law holds for a real dataset of text documents.
#
# The dataset we look at is a collection of the 100 most popular books downloaded from the [Gutenburg Project](https://www.gutenberg.org/browse/scores/top). These 100 books form the corpus that we consider for this problem. Each file contains the text of a book. We will read in all 100 books.
#
# Note: Please *do not* change the folder name or the path, and make sure you use a relative path (e.g. './HW1_Dataset/*filename*) when reading the files. When grading your homework, we will put your Jupyter notebook file and the dataset in the same folder, and run your code. **You will not receive points for this problem if your code fails to load the data.**
#
# Hint: To list all files that match a certain pattern, you can use the `glob` package. Here's an example usage:
#
# ```python
# import glob
# print(glob.glob('./HW1_Dataset/*.txt'))
# ```
#
# **(a) Warm-up/basic Python review [15 pts across subparts].** This part serves as a warm-up, getting you familiar with the kind of code we will be writing in this class. Note that throughout part (a), your code should **not** be using spaCy.
#
# **Subpart i [5 pts].** Write a loop that iterates through all 100 books; for each book, print out its corresponding file name and also how long the book is in terms of string length (meaning that if we load in the book as a string, we compute the length of the string using the built-in Python function `len`; this is just counting the number of characters).
#
# **Please do not actually print out the contents of each book since many of the books are extremely long, and by printing out all the books' contents, you'll end up creating a Jupyter notebook that has a massive file size.**
#
# Hint: When debugging your code, you may want to first make sure your code runs on a few of the books rather than all 100 (for example, you can start by only having 3 of the text files in `HW1_Dataset`). Once you're confident that your solution is correct on a few text files, then run on all of them! This is a standard approach to debugging code that is meant to handle large datasets.
#
# Your output should look like (although there should be 100 books rather than 3 as shown below; also, the ordering of the books might be different on your machine):
#
# ```
# ./HW1_Dataset/War and Peace by graf Leo Tolstoy (251).txt 3227580
# ./HW1_Dataset/Democracy in America — Volume 1 by Alexis de Tocqueville (147).txt 1148435
# ./HW1_Dataset/Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (501).txt 441034
# ```

# %%
import glob
for filename in glob.glob('./HW1_Dataset/*.txt'):
    with open(filename, encoding='utf-8') as f:
        print(filename, len(f.read()))
# Out:
# ./HW1_Dataset/War and Peace by graf Leo Tolstoy (251).txt 3227580
# ./HW1_Dataset/Democracy in America — Volume 1 by Alexis de Tocqueville (147).txt 1148435
# ./HW1_Dataset/Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (501).txt 441034
# ./HW1_Dataset/The King James Version of the Bible (132).txt 4351846
# ./HW1_Dataset/Et dukkehjem. English by Henrik Ibsen (557).txt 161241
# ./HW1_Dataset/Outpost in the Wilderness_ Fort Wayne, 1706-1828 by Charles Poinsatte (161).txt 363234
# ./HW1_Dataset/The Romance of Lust_ A Classic Victorian erotic novel by Anonymous (294).txt 1051148
# ./HW1_Dataset/The Odyssey by Homer (124).txt 697404
# ./HW1_Dataset/A History of Spanish Literature by James Fitzmaurice-Kelly (109).txt 765918
# ./HW1_Dataset/The Philosophy of Spiritual Activity by Rudolf Steiner (144).txt 545031
# ./HW1_Dataset/My Fifteen Lost Years by Florence Elizabeth Maybrick (499).txt 383694
# ./HW1_Dataset/Prestuplenie i nakazanie. English by Fyodor Dostoyevsky (160).txt 1154508
# ./HW1_Dataset/The History of the Peloponnesian War by Thucydides (122).txt 1200021
# ./HW1_Dataset/Gulliver's Travels into Several Remote Nations of the World by Jonathan Swift (136).txt 600105
# ./HW1_Dataset/The Peddler Spy by W. J. Hamilton (356).txt 197390
# ./HW1_Dataset/Dubliners by James Joyce (219).txt 389199
# ./HW1_Dataset/The Hound of the Baskervilles by Arthur Conan Doyle (223).txt 339188
# ./HW1_Dataset/The Boy Fortune Hunters in China by L. Frank  Baum (215).txt 324452
# ./HW1_Dataset/Leviathan by Thomas Hobbes (417).txt 1231784
# ./HW1_Dataset/The Awakening, and Selected Short Stories by Kate Chopin (192).txt 378936
# ./HW1_Dataset/The Interesting Narrative of the Life of Olaudah Equiano, Or Gustavus Vassa, The African by Equiano (114).txt 471165
# ./HW1_Dataset/Through the Looking-Glass by Lewis Carroll (134).txt 181667
# ./HW1_Dataset/Il Principe. English by Niccolò Machiavelli (428) (Unicode Encoding Conflict).txt 300788
# ./HW1_Dataset/On Liberty by John Stuart Mill (116).txt 325922
# ./HW1_Dataset/The Law of Storms by John Wilson Ross (110).txt 65264
# ./HW1_Dataset/The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson (170).txt 159542
# ./HW1_Dataset/Liberalism by L. T.  Hobhouse (119).txt 305345
# ./HW1_Dataset/Semmering 1912 by Peter Altenberg (221).txt 264946
# ./HW1_Dataset/Les Misérables by Victor Hugo (165) (Unicode Encoding Conflict).txt 3254333
# ./HW1_Dataset/The Count of Monte Cristo, Illustrated by Alexandre Dumas (160).txt 2643849
# ./HW1_Dataset/Alice in Wonderland by Lewis Carroll and Alice Gerstenberg (126).txt 104079
# ./HW1_Dataset/Common Sense by Thomas Paine (297).txt 145353
# ./HW1_Dataset/Narrative of the Captivity and Restoration of Mrs. Mary Rowlandson by Mary White Rowlandson (222).txt 123784
# ./HW1_Dataset/The Divine Comedy by Dante, Illustrated by Dante Alighieri (119).txt 2161
# ./HW1_Dataset/The Importance of Being Earnest_ A Trivial Comedy for Serious People by Oscar Wilde (454).txt 138887
# ./HW1_Dataset/Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau (180).txt 656207
# ./HW1_Dataset/The Yellow Wallpaper by Charlotte Perkins Gilman (462).txt 50841
# ./HW1_Dataset/Jane Eyre_ An Autobiography by Charlotte Brontë (290) (Unicode Encoding Conflict).txt 1049267
# ./HW1_Dataset/The Kama Sutra of Vatsyayana by Vatsyayana (172).txt 351664
# ./HW1_Dataset/Sense and Sensibility by Jane Austen (177).txt 693095
# ./HW1_Dataset/Adventures of Huckleberry Finn by Mark Twain (401).txt 593962
# ./HW1_Dataset/Heart of Darkness by Joseph Conrad (213).txt 229835
# ./HW1_Dataset/The Republic by Plato (246).txt 1214387
# ./HW1_Dataset/The Complete Works of William Shakespeare by William Shakespeare (132).txt 5465100
# ./HW1_Dataset/The Picture of Dorian Gray by Oscar Wilde (282).txt 453169
# ./HW1_Dataset/The Works of Edgar Allan Poe — Volume 2 by Edgar Allan Poe (137).txt 569966
# ./HW1_Dataset/Ulysses by James Joyce (282).txt 1534140
# ./HW1_Dataset/The Federalist Papers by Alexander Hamilton and John Jay and James Madison (116).txt 1167141
# ./HW1_Dataset/Leaves of Grass by Walt Whitman (164).txt 757361
# ./HW1_Dataset/Narrative of the Life of Frederick Douglass, an American Slave by Frederick Douglass (243).txt 244263
# ./HW1_Dataset/A Study in Scarlet by Arthur Conan Doyle (163).txt 262340
# ./HW1_Dataset/Beowulf An Anglo-Saxon Epic Poem (403).txt 292953
# ./HW1_Dataset/The Wendigo by Algernon Blackwood (174).txt 127464
# ./HW1_Dataset/The Scarlet Letter by Nathaniel Hawthorne (211).txt 506975
# ./HW1_Dataset/Persuasion by Jane Austen (2234).txt 486251
# ./HW1_Dataset/The Time Machine by H. G.  Wells (137).txt 198281
# ./HW1_Dataset/The Guardsman by Homer Greene (175).txt 412900
# ./HW1_Dataset/Carmilla by Joseph Sheridan Le Fanu (135).txt 176408
# ./HW1_Dataset/Uncle Tom's Cabin by Harriet Beecher Stowe (108).txt 1025501
# ./HW1_Dataset/A Tale of Two Cities by Charles Dickens (425).txt 776702
# ./HW1_Dataset/Moby Dick; Or, The Whale by Herman Melville (413).txt 1238569
# ./HW1_Dataset/Songs of Innocence, and Songs of Experience by William Blake (166).txt 51724
# ./HW1_Dataset/Dracula by Bram Stoker (461).txt 867141
# ./HW1_Dataset/Emma by Jane Austen (166).txt 902390
# ./HW1_Dataset/Wuthering Heights by Emily Brontë (179) (Unicode Encoding Conflict).txt 669150
# ./HW1_Dataset/Autobiography of Benjamin Franklin by Benjamin Franklin (247).txt 458600
# ./HW1_Dataset/The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson (158).txt 158048
# ./HW1_Dataset/Anne of Green Gables by L. M.  Montgomery (114).txt 580635
# ./HW1_Dataset/The Souls of Black Folk by W. E. B.  Du Bois (172).txt 421336
# ./HW1_Dataset/The Confessions of St. Augustine by Bishop of Hippo Saint Augustine (157).txt 622405
# ./HW1_Dataset/Candide by Voltaire (180).txt 224924
# ./HW1_Dataset/The Legend of Sleepy Hollow by Washington Irving (399).txt 89237
# ./HW1_Dataset/Alice's Adventures in Wonderland by Lewis Carroll (564).txt 163817
# ./HW1_Dataset/Peter Pan by J. M.  Barrie (274).txt 278194
# ./HW1_Dataset/The Wonderful Wizard of Oz by L. Frank  Baum (150).txt 227654
# ./HW1_Dataset/The Innocents Abroad by Mark Twain (108).txt 1126278
# ./HW1_Dataset/The Turn of the Screw by Henry James (185).txt 248089
# ./HW1_Dataset/The Adventures of Tom Sawyer by Mark Twain (371).txt 412712
# ./HW1_Dataset/The Tragedy of Romeo and Juliet by William Shakespeare (131).txt 174128
# ./HW1_Dataset/A Modest Proposal by Jonathan Swift (233).txt 38966
# ./HW1_Dataset/A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens (265).txt 177758
# ./HW1_Dataset/Essays of Michel de Montaigne — Complete by Michel de Montaigne (205).txt 3033575
# ./HW1_Dataset/The Adventures of Sherlock Holmes by Arthur Conan Doyle (447).txt 581864
# ./HW1_Dataset/Robert Greene by Robert Greene (126).txt 760655
# ./HW1_Dataset/Essays by Ralph Waldo Emerson by Ralph Waldo Emerson (239).txt 557197
# ./HW1_Dataset/The Boy Fortune Hunters in the South Seas by L. Frank  Baum (150).txt 266166
# ./HW1_Dataset/Pride and Prejudice by Jane Austen (1003).txt 704192
# ./HW1_Dataset/My Secret Life, Volumes I. to III. by Anonymous (157).txt 1378627
# ./HW1_Dataset/The Mysterious Affair at Styles by Agatha Christie (115).txt 340770
# ./HW1_Dataset/Treasure Island by Robert Louis Stevenson (236).txt 383675
# ./HW1_Dataset/Hedda Gabler by Henrik Ibsen (123).txt 193875
# ./HW1_Dataset/Metamorphosis by Franz Kafka (483).txt 139056
# ./HW1_Dataset/Great Expectations by Charles Dickens (293).txt 1013450
# ./HW1_Dataset/The Life and Adventures of Robinson Crusoe by Daniel Defoe (126).txt 642909
# ./HW1_Dataset/The Iliad by Homer (256).txt 1175588
# ./HW1_Dataset/The Tragical History of Doctor Faustus by Christopher Marlowe (144).txt 143736
# ./HW1_Dataset/Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm (429).txt 540241
# ./HW1_Dataset/Beyond Good and Evil by Friedrich Wilhelm Nietzsche (120).txt 402273
# ./HW1_Dataset/Siddhartha by Hermann Hesse (216).txt 236855
# ./HW1_Dataset/The Faery Queen and Her Knights by Alfred John Church (177).txt 447320

# %% [markdown]
# **Subpart ii [5 pts].** Copy and paste your code from **subpart i** into the code cell below. Then in the code cell below, modify the code so that it prints out the top 15 longest books (in terms of raw string length, which is what you had already computed). In particular, please write your code so that the printout is of the following format:
#
# ```
# 1. <number of characters in longest text file> <filename of longest text file>
# 2. <number of characters in 2nd longest text file> <filename of 2nd longest text file>
# ...
# 15. <number of characters in 15th longest text file> <filename of 15th longest text file>
# ```
#
# Note: only print out information for the top 15 books in the format above, and do not print out what we asked you to print in **subpart i**.

# %%
import glob

filename_length_pairs = []
for filename in glob.glob('./HW1_Dataset/*.txt'):
    with open(filename, encoding='utf-8') as f:
        filename_length_pairs.append((len(f.read()), filename))

for rank, (str_len, filename) in enumerate(sorted(filename_length_pairs, reverse=True)[:15]):
    print(rank+1, str_len, filename)
# Out:
# 1 5465100 ./HW1_Dataset/The Complete Works of William Shakespeare by William Shakespeare (132).txt
# 2 4351846 ./HW1_Dataset/The King James Version of the Bible (132).txt
# 3 3254333 ./HW1_Dataset/Les Misérables by Victor Hugo (165) (Unicode Encoding Conflict).txt
# 4 3227580 ./HW1_Dataset/War and Peace by graf Leo Tolstoy (251).txt
# 5 3033575 ./HW1_Dataset/Essays of Michel de Montaigne — Complete by Michel de Montaigne (205).txt
# 6 2643849 ./HW1_Dataset/The Count of Monte Cristo, Illustrated by Alexandre Dumas (160).txt
# 7 1534140 ./HW1_Dataset/Ulysses by James Joyce (282).txt
# 8 1378627 ./HW1_Dataset/My Secret Life, Volumes I. to III. by Anonymous (157).txt
# 9 1238569 ./HW1_Dataset/Moby Dick; Or, The Whale by Herman Melville (413).txt
# 10 1231784 ./HW1_Dataset/Leviathan by Thomas Hobbes (417).txt
# 11 1214387 ./HW1_Dataset/The Republic by Plato (246).txt
# 12 1200021 ./HW1_Dataset/The History of the Peloponnesian War by Thucydides (122).txt
# 13 1175588 ./HW1_Dataset/The Iliad by Homer (256).txt
# 14 1167141 ./HW1_Dataset/The Federalist Papers by Alexander Hamilton and John Jay and James Madison (116).txt
# 15 1154508 ./HW1_Dataset/Prestuplenie i nakazanie. English by Fyodor Dostoyevsky (160).txt

# %% [markdown]
# **Subpart iii [5 pts].** You should find that some of the books are quite long. Processing very long books will be problematic with spaCy, so we will want to chop up long books into pieces. Note that much later on in the course, we shall see that chopping up large amounts of data into small "batches" is in fact quite common in machine learning since typically we cannot hope to store and process massive datasets on a CPU or GPU all at once!
#
# As a concrete example, suppose that a book's text was `'cat dog shark spam eggs'` and we wanted to split it up into batches where each batch has at most 3 words. Then we would split up the book's text into two batches/pieces: `'cat dog shark'` and `'spam eggs'`.
#
# We have provided code for you to do this below.

# %%
import numpy as np

def split_into_batches(book_text, max_num_words_per_batch):
    words_split_on_spaces = book_text.split(' ')
    num_book_pieces = int(np.ceil(len(words_split_on_spaces) / max_num_words_per_batch))
    batches = []
    for piece_idx in range(num_book_pieces):
        start_idx = piece_idx * max_num_words_per_batch
        end_idx = (piece_idx + 1) * max_num_words_per_batch
        if end_idx > len(words_split_on_spaces):
            end_idx = len(words_split_on_spaces)
        book_piece = ' '.join(words_split_on_spaces[start_idx:end_idx])
        batches.append(book_piece)
    return batches

print(split_into_batches('cat dog shark spam eggs', 3))
# Out:
# ['cat dog shark', 'spam eggs']

# %% [markdown]
# Now write a loop that goes through all 100 books again. However, for each book, split it up into batches so that each batch has at most 10000 words. In this case, how many batches are there total across all 100 books? Please write code that computes this number of batches. Your code should print out the following (with the correct total number of batches):
#
# ```
# Total number of batches: <total number of batches across all 100 books>
# ```

# %%
total_num_batches = 0
for filename in glob.glob('./HW1_Dataset/*.txt'):
    with open(filename, encoding='utf-8') as f:
        total_num_batches += len(split_into_batches(f.read(), 20000))
print('Total number of batches:', total_num_batches)
# Out:
# Total number of batches: 650

# %% [markdown]
# **(b) [10 pts]** Now we will finally use spaCy. Note that for this problem, you don't actually need `spaCy`'s named entity recognition or grammatical parsing. Turning these elements off when you instantiate the `nlp` object can substantially speed up your code. To make sure these are off when instantiating the `nlp` object, call:
#
# ```python
# nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser'])
# ```
#
# **Throughout this problem, do not remove stopwords.**
#
# Build a term frequency (raw counts) table that is for all 100 books. Specifically, building on your solution to part (a)-subpart iii, read in a single book at a time and for each book, do the following:
#
#   1. Split it up into batches where each batch has at most 10000 words.
#   2. For each batch:
#     1. Process the batch by separating and lemmatizing the words
#     2. Count the number of times each lemma appears and add these to the frequency table. For simplicity, **do not convert lemmas to lowercase**. (Note that we use raw counts as the "frequency"--do not do any division.) Also, as we explain below, we will only count lemmas that are alphabetic.
#
# Note that just as we had said in part (a): do **not** print out the complete contents of every book since doing so will result in a Jupyter notebook file that is massive.
#
# After looping through all 100 books, you should have the term frequency table for the entire corpus (importantly, the frequency table should not just be for a single book; it should be for all 100 books). Sort the table and print the top 50 most frequent words, along with their frequencies and ranks. Don't worry about ties (for example, if multiple things have the same frequency, it's fine if your solution breaks ties arbitrarily in the sorting).
#
# Note: When counting the lemmas, only include lemmas that consist of alphabetic letters (a-z and A-Z). You can do this with what's called a *regular expression*. For example, to check whether the words "will.i.am" or "Tesla" are alphabetic, you would do the following:
#
# ```python
# import re  # regular expression package
# if re.match('[a-zA-Z]+$', 'will.i.am'):
#     print('will.i.am consists only of alphabetic letters!')
# if re.match('[a-zA-Z]+$', 'Tesla'):
#     print('tesla consists only of alphabetic letters!')
# ```

# %%
import spacy
import re
from collections import Counter
import time

tic = time.time()
nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser'])

histogram = Counter()
batch_idx = 0
for filename in glob.glob('./HW1_Dataset/*.txt'):
    with open(filename, encoding='utf-8') as f:
        text = f.read()
        for batch in split_into_batches(text, 20000):
            batch_tic = time.time()
            
            print('Processing batch %d of %d...' % (batch_idx + 1, total_num_batches), end=' ')
            parsed_batch = nlp(batch)
            for token in parsed_batch:
                lemma = token.lemma_
                if re.match('[a-zA-Z]+$', lemma):
                    histogram[lemma] += 1
            batch_idx += 1
            
            print('Time elapsed: %f second(s)' % (time.time() - batch_tic))
print('Total time elapsed: %f second(s)' % (time.time() - tic))
# Out:
# Processing batch 1 of 650... Time elapsed: 0.816092 second(s)
# Processing batch 2 of 650... Time elapsed: 0.721100 second(s)
# Processing batch 3 of 650... Time elapsed: 0.724876 second(s)
# Processing batch 4 of 650... Time elapsed: 0.697452 second(s)
# Processing batch 5 of 650... Time elapsed: 0.679650 second(s)
# Processing batch 6 of 650... Time elapsed: 0.657338 second(s)
# Processing batch 7 of 650... Time elapsed: 0.688678 second(s)
# Processing batch 8 of 650... Time elapsed: 0.703256 second(s)
# Processing batch 9 of 650... Time elapsed: 0.690213 second(s)
# Processing batch 10 of 650... Time elapsed: 0.672252 second(s)
# Processing batch 11 of 650... Time elapsed: 0.694697 second(s)
# Processing batch 12 of 650... Time elapsed: 0.665694 second(s)
# Processing batch 13 of 650... Time elapsed: 0.682326 second(s)
# Processing batch 14 of 650... Time elapsed: 0.664801 second(s)
# Processing batch 15 of 650... Time elapsed: 0.685638 second(s)
# Processing batch 16 of 650... Time elapsed: 0.690980 second(s)
# Processing batch 17 of 650... Time elapsed: 0.666884 second(s)
# Processing batch 18 of 650... Time elapsed: 0.652778 second(s)
# Processing batch 19 of 650... Time elapsed: 0.722607 second(s)
# Processing batch 20 of 650... Time elapsed: 0.683670 second(s)
# Processing batch 21 of 650... Time elapsed: 0.638862 second(s)
# Processing batch 22 of 650... Time elapsed: 0.709468 second(s)
# Processing batch 23 of 650... Time elapsed: 0.709935 second(s)
# Processing batch 24 of 650... Time elapsed: 0.675809 second(s)
# Processing batch 25 of 650... Time elapsed: 0.694343 second(s)
# Processing batch 26 of 650... Time elapsed: 0.626198 second(s)
# Processing batch 27 of 650... Time elapsed: 0.764293 second(s)
# Processing batch 28 of 650... Time elapsed: 0.811596 second(s)
# Processing batch 29 of 650... Time elapsed: 1.332706 second(s)
# Processing batch 30 of 650... Time elapsed: 1.029411 second(s)
# Processing batch 31 of 650... Time elapsed: 1.072768 second(s)
# Processing batch 32 of 650... Time elapsed: 1.027918 second(s)
# Processing batch 33 of 650... Time elapsed: 0.800539 second(s)
# Processing batch 34 of 650... Time elapsed: 0.844213 second(s)
# Processing batch 35 of 650... Time elapsed: 0.729941 second(s)
# Processing batch 36 of 650... Time elapsed: 0.767151 second(s)
# Processing batch 37 of 650... Time elapsed: 0.761240 second(s)
# Processing batch 38 of 650... Time elapsed: 0.739259 second(s)
# Processing batch 39 of 650... Time elapsed: 0.541495 second(s)
# Processing batch 40 of 650... Time elapsed: 0.769270 second(s)
# Processing batch 41 of 650... Time elapsed: 0.814254 second(s)
# Processing batch 42 of 650... Time elapsed: 0.819152 second(s)
# Processing batch 43 of 650... Time elapsed: 0.754490 second(s)
# Processing batch 44 of 650... Time elapsed: 0.753721 second(s)
# Processing batch 45 of 650... Time elapsed: 0.811402 second(s)
# Processing batch 46 of 650... Time elapsed: 0.791311 second(s)
# Processing batch 47 of 650... Time elapsed: 0.836290 second(s)
# Processing batch 48 of 650... Time elapsed: 0.833769 second(s)
# Processing batch 49 of 650... Time elapsed: 1.063377 second(s)
# Processing batch 50 of 650... Time elapsed: 1.064432 second(s)
# Processing batch 51 of 650... Time elapsed: 0.839491 second(s)
# Processing batch 52 of 650... Time elapsed: 0.782225 second(s)
# Processing batch 53 of 650... Time elapsed: 0.814367 second(s)
# Processing batch 54 of 650... Time elapsed: 0.833282 second(s)
# Processing batch 55 of 650... Time elapsed: 0.822025 second(s)
# Processing batch 56 of 650... Time elapsed: 0.798737 second(s)
# Processing batch 57 of 650... Time elapsed: 0.830723 second(s)
# Processing batch 58 of 650... Time elapsed: 0.807430 second(s)
# Processing batch 59 of 650... Time elapsed: 0.861365 second(s)
# Processing batch 60 of 650... Time elapsed: 0.847040 second(s)
# Processing batch 61 of 650... Time elapsed: 0.824537 second(s)
# Processing batch 62 of 650... Time elapsed: 0.834630 second(s)
# Processing batch 63 of 650... Time elapsed: 0.841741 second(s)
# Processing batch 64 of 650... Time elapsed: 0.836352 second(s)
# Processing batch 65 of 650... Time elapsed: 0.813419 second(s)
# Processing batch 66 of 650... Time elapsed: 0.808933 second(s)
# Processing batch 67 of 650... Time elapsed: 0.823613 second(s)
# Processing batch 68 of 650... Time elapsed: 0.802593 second(s)
# Processing batch 69 of 650... Time elapsed: 1.199400 second(s)
# Processing batch 70 of 650... Time elapsed: 1.119329 second(s)
# Processing batch 71 of 650... Time elapsed: 1.315535 second(s)
# Processing batch 72 of 650... Time elapsed: 1.322424 second(s)
# Processing batch 73 of 650... Time elapsed: 1.221869 second(s)
# Processing batch 74 of 650... Time elapsed: 0.948092 second(s)
# Processing batch 75 of 650... Time elapsed: 0.896379 second(s)
# Processing batch 76 of 650... Time elapsed: 0.893348 second(s)
# Processing batch 77 of 650... Time elapsed: 0.500298 second(s)
# Processing batch 78 of 650... Time elapsed: 1.017714 second(s)
# Processing batch 79 of 650... Time elapsed: 0.365768 second(s)
# Processing batch 80 of 650... Time elapsed: 1.644976 second(s)
# Processing batch 81 of 650... Time elapsed: 1.566386 second(s)
# Processing batch 82 of 650... Time elapsed: 1.322277 second(s)
# Processing batch 83 of 650... Time elapsed: 1.268520 second(s)
# Processing batch 84 of 650... Time elapsed: 1.225564 second(s)
# Processing batch 85 of 650... Time elapsed: 1.030051 second(s)
# Processing batch 86 of 650... Time elapsed: 0.820659 second(s)
# Processing batch 87 of 650... Time elapsed: 0.841639 second(s)
# Processing batch 88 of 650... Time elapsed: 0.893363 second(s)
# Processing batch 89 of 650... Time elapsed: 0.808968 second(s)
# Processing batch 90 of 650... Time elapsed: 1.021422 second(s)
# Processing batch 91 of 650... Time elapsed: 0.778927 second(s)
# Processing batch 92 of 650... Time elapsed: 0.938220 second(s)
# Processing batch 93 of 650... Time elapsed: 0.858783 second(s)
# Processing batch 94 of 650... Time elapsed: 0.827601 second(s)
# Processing batch 95 of 650... Time elapsed: 0.866043 second(s)
# Processing batch 96 of 650... Time elapsed: 0.854460 second(s)
# Processing batch 97 of 650... Time elapsed: 0.959241 second(s)
# Processing batch 98 of 650... Time elapsed: 0.121087 second(s)
# Processing batch 99 of 650... Time elapsed: 1.135041 second(s)
# Processing batch 100 of 650... Time elapsed: 1.112140 second(s)
# Processing batch 101 of 650... Time elapsed: 1.354896 second(s)
# Processing batch 102 of 650... Time elapsed: 1.317351 second(s)
# Processing batch 103 of 650... Time elapsed: 1.640705 second(s)
# Processing batch 104 of 650... Time elapsed: 1.715638 second(s)
# Processing batch 105 of 650... Time elapsed: 0.009356 second(s)
# Processing batch 106 of 650... Time elapsed: 0.788680 second(s)
# Processing batch 107 of 650... Time elapsed: 1.069723 second(s)
# Processing batch 108 of 650... Time elapsed: 0.872935 second(s)
# Processing batch 109 of 650... Time elapsed: 0.939145 second(s)
# Processing batch 110 of 650... Time elapsed: 0.384375 second(s)
# Processing batch 111 of 650... Time elapsed: 0.874548 second(s)
# Processing batch 112 of 650... Time elapsed: 1.017657 second(s)
# Processing batch 113 of 650... Time elapsed: 0.940136 second(s)
# Processing batch 114 of 650... Time elapsed: 0.186997 second(s)
# Processing batch 115 of 650... Time elapsed: 0.920884 second(s)
# Processing batch 116 of 650... Time elapsed: 0.838968 second(s)
# Processing batch 117 of 650... Time elapsed: 0.908237 second(s)
# Processing batch 118 of 650... Time elapsed: 0.908514 second(s)
# Processing batch 119 of 650... Time elapsed: 0.885288 second(s)
# Processing batch 120 of 650... Time elapsed: 0.897954 second(s)
# Processing batch 121 of 650... Time elapsed: 0.914303 second(s)
# Processing batch 122 of 650... Time elapsed: 0.814243 second(s)
# Processing batch 123 of 650... Time elapsed: 0.828601 second(s)
# Processing batch 124 of 650... Time elapsed: 0.352492 second(s)
# Processing batch 125 of 650... Time elapsed: 0.815456 second(s)
# Processing batch 126 of 650... Time elapsed: 0.839209 second(s)
# Processing batch 127 of 650... Time elapsed: 0.878410 second(s)
# Processing batch 128 of 650... Time elapsed: 0.899760 second(s)
# Processing batch 129 of 650... Time elapsed: 0.758379 second(s)
# Processing batch 130 of 650... Time elapsed: 0.867160 second(s)
# Processing batch 131 of 650... Time elapsed: 0.769695 second(s)
# Processing batch 132 of 650... Time elapsed: 0.832912 second(s)
# Processing batch 133 of 650... Time elapsed: 0.840452 second(s)
# Processing batch 134 of 650... Time elapsed: 0.510665 second(s)
# Processing batch 135 of 650... Time elapsed: 0.859998 second(s)
# Processing batch 136 of 650... Time elapsed: 0.901408 second(s)
# Processing batch 137 of 650... Time elapsed: 0.996116 second(s)
# Processing batch 138 of 650... Time elapsed: 1.228730 second(s)
# Processing batch 139 of 650... Time elapsed: 1.124790 second(s)
# Processing batch 140 of 650... Time elapsed: 0.100898 second(s)
# Processing batch 141 of 650... Time elapsed: 1.022280 second(s)
# Processing batch 142 of 650... Time elapsed: 0.809593 second(s)
# Processing batch 143 of 650... Time elapsed: 1.344868 second(s)
# Processing batch 144 of 650... Time elapsed: 0.939832 second(s)
# Processing batch 145 of 650... Time elapsed: 1.084644 second(s)
# Processing batch 146 of 650... Time elapsed: 0.258521 second(s)
# Processing batch 147 of 650... Time elapsed: 0.929899 second(s)
# Processing batch 148 of 650... Time elapsed: 1.072303 second(s)
# Processing batch 149 of 650... Time elapsed: 1.049062 second(s)
# Processing batch 150 of 650... Time elapsed: 0.895817 second(s)
# Processing batch 151 of 650... Time elapsed: 0.985087 second(s)
# Processing batch 152 of 650... Time elapsed: 0.748716 second(s)
# Processing batch 153 of 650... Time elapsed: 1.098620 second(s)
# Processing batch 154 of 650... Time elapsed: 0.966385 second(s)
# Processing batch 155 of 650... Time elapsed: 1.128282 second(s)
# Processing batch 156 of 650... Time elapsed: 0.968696 second(s)
# Processing batch 157 of 650... Time elapsed: 1.002768 second(s)
# Processing batch 158 of 650... Time elapsed: 0.954506 second(s)
# Processing batch 159 of 650... Time elapsed: 0.956989 second(s)
# Processing batch 160 of 650... Time elapsed: 0.977980 second(s)
# Processing batch 161 of 650... Time elapsed: 1.039528 second(s)
# Processing batch 162 of 650... Time elapsed: 0.940408 second(s)
# Processing batch 163 of 650... Time elapsed: 0.888574 second(s)
# Processing batch 164 of 650... Time elapsed: 0.905319 second(s)
# Processing batch 165 of 650... Time elapsed: 0.938324 second(s)
# Processing batch 166 of 650... Time elapsed: 0.085328 second(s)
# Processing batch 167 of 650... Time elapsed: 0.857062 second(s)
# Processing batch 168 of 650... Time elapsed: 0.862055 second(s)
# Processing batch 169 of 650... Time elapsed: 0.776935 second(s)
# Processing batch 170 of 650... Time elapsed: 0.753630 second(s)
# Processing batch 171 of 650... Time elapsed: 0.235771 second(s)
# Processing batch 172 of 650... Time elapsed: 0.899275 second(s)
# Processing batch 173 of 650... Time elapsed: 0.570542 second(s)
# Processing batch 174 of 650... Time elapsed: 0.827584 second(s)
# Processing batch 175 of 650... Time elapsed: 0.826364 second(s)
# Processing batch 176 of 650... Time elapsed: 0.432462 second(s)
# Processing batch 177 of 650... Time elapsed: 0.918902 second(s)
# Processing batch 178 of 650... Time elapsed: 0.900074 second(s)
# Processing batch 179 of 650... Time elapsed: 0.479665 second(s)
# Processing batch 180 of 650... Time elapsed: 0.518497 second(s)
# Processing batch 181 of 650... Time elapsed: 0.881803 second(s)
# Processing batch 182 of 650... Time elapsed: 0.302854 second(s)
# Processing batch 183 of 650... Time elapsed: 0.915766 second(s)
# Processing batch 184 of 650... Time elapsed: 0.820056 second(s)
# Processing batch 185 of 650... Time elapsed: 0.381667 second(s)
# Processing batch 186 of 650... Time elapsed: 0.888473 second(s)
# Processing batch 187 of 650... Time elapsed: 1.116267 second(s)
# Processing batch 188 of 650... Time elapsed: 0.538247 second(s)
# Processing batch 189 of 650... Time elapsed: 0.888986 second(s)
# Processing batch 190 of 650... Time elapsed: 0.925640 second(s)
# Processing batch 191 of 650... Time elapsed: 0.840192 second(s)
# Processing batch 192 of 650... Time elapsed: 0.846951 second(s)
# Processing batch 193 of 650... Time elapsed: 0.842892 second(s)
# Processing batch 194 of 650... Time elapsed: 0.833243 second(s)
# Processing batch 195 of 650... Time elapsed: 1.030217 second(s)
# Processing batch 196 of 650... Time elapsed: 0.910212 second(s)
# Processing batch 197 of 650... Time elapsed: 0.886153 second(s)
# Processing batch 198 of 650... Time elapsed: 0.941841 second(s)
# Processing batch 199 of 650... Time elapsed: 0.967514 second(s)
# Processing batch 200 of 650... Time elapsed: 1.000146 second(s)
# Processing batch 201 of 650... Time elapsed: 0.920143 second(s)
# Processing batch 202 of 650... Time elapsed: 0.870861 second(s)
# Processing batch 203 of 650... Time elapsed: 0.912655 second(s)
# Processing batch 204 of 650... Time elapsed: 0.854589 second(s)
# Processing batch 205 of 650... Time elapsed: 0.878596 second(s)
# Processing batch 206 of 650... Time elapsed: 0.907617 second(s)
# Processing batch 207 of 650... Time elapsed: 0.927318 second(s)
# Processing batch 208 of 650... Time elapsed: 0.851091 second(s)
# Processing batch 209 of 650... Time elapsed: 0.872171 second(s)
# Processing batch 210 of 650... Time elapsed: 0.973970 second(s)
# Processing batch 211 of 650... Time elapsed: 0.908207 second(s)
# Processing batch 212 of 650... Time elapsed: 0.981358 second(s)
# Processing batch 213 of 650... Time elapsed: 0.933521 second(s)
# Processing batch 214 of 650... Time elapsed: 0.946521 second(s)
# Processing batch 215 of 650... Time elapsed: 0.095365 second(s)
# Processing batch 216 of 650... Time elapsed: 0.959299 second(s)
# Processing batch 217 of 650... Time elapsed: 0.968485 second(s)
# Processing batch 218 of 650... Time elapsed: 0.954012 second(s)
# Processing batch 219 of 650... Time elapsed: 0.859564 second(s)
# Processing batch 220 of 650... Time elapsed: 0.939524 second(s)
# Processing batch 221 of 650... Time elapsed: 0.891988 second(s)
# Processing batch 222 of 650... Time elapsed: 0.889647 second(s)
# Processing batch 223 of 650... Time elapsed: 0.924097 second(s)
# Processing batch 224 of 650... Time elapsed: 0.882374 second(s)
# Processing batch 225 of 650... Time elapsed: 0.886999 second(s)
# Processing batch 226 of 650... Time elapsed: 0.868455 second(s)
# Processing batch 227 of 650... Time elapsed: 0.917991 second(s)
# Processing batch 228 of 650... Time elapsed: 0.874984 second(s)
# Processing batch 229 of 650... Time elapsed: 1.274151 second(s)
# Processing batch 230 of 650... Time elapsed: 1.435279 second(s)
# Processing batch 231 of 650... Time elapsed: 1.128970 second(s)
# Processing batch 232 of 650... Time elapsed: 0.945603 second(s)
# Processing batch 233 of 650... Time elapsed: 0.872850 second(s)
# Processing batch 234 of 650... Time elapsed: 0.887951 second(s)
# Processing batch 235 of 650... Time elapsed: 0.871759 second(s)
# Processing batch 236 of 650... Time elapsed: 0.879448 second(s)
# Processing batch 237 of 650... Time elapsed: 0.800729 second(s)
# Processing batch 238 of 650... Time elapsed: 0.879496 second(s)
# Processing batch 239 of 650... Time elapsed: 0.208668 second(s)
# Processing batch 240 of 650... Time elapsed: 0.806190 second(s)
# Processing batch 241 of 650... Time elapsed: 0.072111 second(s)
# Processing batch 242 of 650... Time elapsed: 0.016621 second(s)
# Processing batch 243 of 650... Time elapsed: 0.901320 second(s)
# Processing batch 244 of 650... Time elapsed: 0.173175 second(s)
# Processing batch 245 of 650... Time elapsed: 0.810055 second(s)
# Processing batch 246 of 650... Time elapsed: 0.913830 second(s)
# Processing batch 247 of 650... Time elapsed: 0.842010 second(s)
# Processing batch 248 of 650... Time elapsed: 0.797884 second(s)
# Processing batch 249 of 650... Time elapsed: 0.931532 second(s)
# Processing batch 250 of 650... Time elapsed: 0.544329 second(s)
# Processing batch 251 of 650... Time elapsed: 0.325198 second(s)
# Processing batch 252 of 650... Time elapsed: 0.895230 second(s)
# Processing batch 253 of 650... Time elapsed: 0.883553 second(s)
# Processing batch 254 of 650... Time elapsed: 0.846160 second(s)
# Processing batch 255 of 650... Time elapsed: 0.906721 second(s)
# Processing batch 256 of 650... Time elapsed: 0.953165 second(s)
# Processing batch 257 of 650... Time elapsed: 0.897751 second(s)
# Processing batch 258 of 650... Time elapsed: 0.904412 second(s)
# Processing batch 259 of 650... Time elapsed: 0.865241 second(s)
# Processing batch 260 of 650... Time elapsed: 0.742058 second(s)
# Processing batch 261 of 650... Time elapsed: 0.798442 second(s)
# Processing batch 262 of 650... Time elapsed: 0.796844 second(s)
# Processing batch 263 of 650... Time elapsed: 0.775505 second(s)
# Processing batch 264 of 650... Time elapsed: 0.814709 second(s)
# Processing batch 265 of 650... Time elapsed: 0.795881 second(s)
# Processing batch 266 of 650... Time elapsed: 0.774163 second(s)
# Processing batch 267 of 650... Time elapsed: 0.761226 second(s)
# Processing batch 268 of 650... Time elapsed: 0.782678 second(s)
# Processing batch 269 of 650... Time elapsed: 0.596783 second(s)
# Processing batch 270 of 650... Time elapsed: 0.892024 second(s)
# Processing batch 271 of 650... Time elapsed: 0.848914 second(s)
# Processing batch 272 of 650... Time elapsed: 0.873035 second(s)
# Processing batch 273 of 650... Time elapsed: 0.875231 second(s)
# Processing batch 274 of 650... Time elapsed: 0.821927 second(s)
# Processing batch 275 of 650... Time elapsed: 0.212549 second(s)
# Processing batch 276 of 650... Time elapsed: 0.830303 second(s)
# Processing batch 277 of 650... Time elapsed: 0.901003 second(s)
# Processing batch 278 of 650... Time elapsed: 0.845053 second(s)
# Processing batch 279 of 650... Time elapsed: 0.821574 second(s)
# Processing batch 280 of 650... Time elapsed: 0.922136 second(s)
# Processing batch 281 of 650... Time elapsed: 0.754008 second(s)
# Processing batch 282 of 650... Time elapsed: 0.777437 second(s)
# Processing batch 283 of 650... Time elapsed: 0.844954 second(s)
# Processing batch 284 of 650... Time elapsed: 0.825374 second(s)
# Processing batch 285 of 650... Time elapsed: 0.797272 second(s)
# Processing batch 286 of 650... Time elapsed: 0.873994 second(s)
# Processing batch 287 of 650... Time elapsed: 0.814622 second(s)
# Processing batch 288 of 650... Time elapsed: 0.718300 second(s)
# Processing batch 289 of 650... Time elapsed: 0.718541 second(s)
# Processing batch 290 of 650... Time elapsed: 0.666429 second(s)
# Processing batch 291 of 650... Time elapsed: 0.760110 second(s)
# Processing batch 292 of 650... Time elapsed: 0.590140 second(s)
# Processing batch 293 of 650... Time elapsed: 0.629478 second(s)
# Processing batch 294 of 650... Time elapsed: 0.788781 second(s)
# Processing batch 295 of 650... Time elapsed: 0.794900 second(s)
# Processing batch 296 of 650... Time elapsed: 0.717922 second(s)
# Processing batch 297 of 650... Time elapsed: 0.606641 second(s)
# Processing batch 298 of 650... Time elapsed: 0.692330 second(s)
# Processing batch 299 of 650... Time elapsed: 0.683297 second(s)
# Processing batch 300 of 650... Time elapsed: 0.606292 second(s)
# Processing batch 301 of 650... Time elapsed: 0.586993 second(s)
# Processing batch 302 of 650... Time elapsed: 0.716315 second(s)
# Processing batch 303 of 650... Time elapsed: 0.644272 second(s)
# Processing batch 304 of 650... Time elapsed: 0.690757 second(s)
# Processing batch 305 of 650... Time elapsed: 0.684664 second(s)
# Processing batch 306 of 650... Time elapsed: 0.698325 second(s)
# Processing batch 307 of 650... Time elapsed: 0.650942 second(s)
# Processing batch 308 of 650... Time elapsed: 0.616768 second(s)
# Processing batch 309 of 650... Time elapsed: 0.623402 second(s)
# Processing batch 310 of 650... Time elapsed: 0.749733 second(s)
# Processing batch 311 of 650... Time elapsed: 0.630957 second(s)
# Processing batch 312 of 650... Time elapsed: 0.729705 second(s)
# Processing batch 313 of 650... Time elapsed: 0.745329 second(s)
# Processing batch 314 of 650... Time elapsed: 0.690879 second(s)
# Processing batch 315 of 650... Time elapsed: 0.810535 second(s)
# Processing batch 316 of 650... Time elapsed: 0.690399 second(s)
# Processing batch 317 of 650... Time elapsed: 0.767352 second(s)
# Processing batch 318 of 650... Time elapsed: 0.866866 second(s)
# Processing batch 319 of 650... Time elapsed: 0.767023 second(s)
# Processing batch 320 of 650... Time elapsed: 0.725731 second(s)
# Processing batch 321 of 650... Time elapsed: 0.849616 second(s)
# Processing batch 322 of 650... Time elapsed: 0.865768 second(s)
# Processing batch 323 of 650... Time elapsed: 0.743390 second(s)
# Processing batch 324 of 650... Time elapsed: 0.916428 second(s)
# Processing batch 325 of 650... Time elapsed: 1.197330 second(s)
# Processing batch 326 of 650... Time elapsed: 1.047526 second(s)
# Processing batch 327 of 650... Time elapsed: 1.281182 second(s)
# Processing batch 328 of 650... Time elapsed: 0.894603 second(s)
# Processing batch 329 of 650... Time elapsed: 0.680146 second(s)
# Processing batch 330 of 650... Time elapsed: 0.752131 second(s)
# Processing batch 331 of 650... Time elapsed: 0.881160 second(s)
# Processing batch 332 of 650... Time elapsed: 0.634802 second(s)
# Processing batch 333 of 650... Time elapsed: 0.686380 second(s)
# Processing batch 334 of 650... Time elapsed: 0.821239 second(s)
# Processing batch 335 of 650... Time elapsed: 0.745605 second(s)
# Processing batch 336 of 650... Time elapsed: 0.808948 second(s)
# Processing batch 337 of 650... Time elapsed: 0.737459 second(s)
# Processing batch 338 of 650... Time elapsed: 0.708093 second(s)
# Processing batch 339 of 650... Time elapsed: 0.771547 second(s)
# Processing batch 340 of 650... Time elapsed: 0.731311 second(s)
# Processing batch 341 of 650... Time elapsed: 0.723694 second(s)
# Processing batch 342 of 650... Time elapsed: 0.774928 second(s)
# Processing batch 343 of 650... Time elapsed: 0.793856 second(s)
# Processing batch 344 of 650... Time elapsed: 0.839684 second(s)
# Processing batch 345 of 650... Time elapsed: 0.785823 second(s)
# Processing batch 346 of 650... Time elapsed: 0.887272 second(s)
# Processing batch 347 of 650... Time elapsed: 0.748654 second(s)
# Processing batch 348 of 650... Time elapsed: 0.800036 second(s)
# Processing batch 349 of 650... Time elapsed: 0.782989 second(s)
# Processing batch 350 of 650... Time elapsed: 0.811342 second(s)
# Processing batch 351 of 650... Time elapsed: 0.737572 second(s)
# Processing batch 352 of 650... Time elapsed: 0.369523 second(s)
# Processing batch 353 of 650... Time elapsed: 0.904800 second(s)
# Processing batch 354 of 650... Time elapsed: 0.865690 second(s)
# Processing batch 355 of 650... Time elapsed: 0.933065 second(s)
# Processing batch 356 of 650... Time elapsed: 0.864281 second(s)
# Processing batch 357 of 650... Time elapsed: 0.874954 second(s)
# Processing batch 358 of 650... Time elapsed: 1.162031 second(s)
# Processing batch 359 of 650... Time elapsed: 1.175675 second(s)
# Processing batch 360 of 650... Time elapsed: 1.042219 second(s)
# Processing batch 361 of 650... Time elapsed: 0.620778 second(s)
# Processing batch 362 of 650... Time elapsed: 1.441144 second(s)
# Processing batch 363 of 650... Time elapsed: 1.566819 second(s)
# Processing batch 364 of 650... Time elapsed: 1.449805 second(s)
# Processing batch 365 of 650... Time elapsed: 1.460368 second(s)
# Processing batch 366 of 650... Time elapsed: 1.673558 second(s)
# Processing batch 367 of 650... Time elapsed: 1.086382 second(s)
# Processing batch 368 of 650... Time elapsed: 0.973889 second(s)
# Processing batch 369 of 650... Time elapsed: 1.267321 second(s)
# Processing batch 370 of 650... Time elapsed: 1.202545 second(s)
# Processing batch 371 of 650... Time elapsed: 0.898297 second(s)
# Processing batch 372 of 650... Time elapsed: 1.127234 second(s)
# Processing batch 373 of 650... Time elapsed: 0.729657 second(s)
# Processing batch 374 of 650... Time elapsed: 0.247016 second(s)
# Processing batch 375 of 650... Time elapsed: 0.871615 second(s)
# Processing batch 376 of 650... Time elapsed: 0.924547 second(s)
# Processing batch 377 of 650... Time elapsed: 0.911227 second(s)
# Processing batch 378 of 650... Time elapsed: 1.084497 second(s)
# Processing batch 379 of 650... Time elapsed: 0.981432 second(s)
# Processing batch 380 of 650... Time elapsed: 0.815014 second(s)
# Processing batch 381 of 650... Time elapsed: 0.834305 second(s)
# Processing batch 382 of 650... Time elapsed: 0.828445 second(s)
# Processing batch 383 of 650... Time elapsed: 0.737000 second(s)
# Processing batch 384 of 650... Time elapsed: 0.761022 second(s)
# Processing batch 385 of 650... Time elapsed: 0.736185 second(s)
# Processing batch 386 of 650... Time elapsed: 0.751791 second(s)
# Processing batch 387 of 650... Time elapsed: 0.841915 second(s)
# Processing batch 388 of 650... Time elapsed: 0.758862 second(s)
# Processing batch 389 of 650... Time elapsed: 0.789023 second(s)
# Processing batch 390 of 650... Time elapsed: 0.805721 second(s)
# Processing batch 391 of 650... Time elapsed: 0.635011 second(s)
# Processing batch 392 of 650... Time elapsed: 0.945173 second(s)
# Processing batch 393 of 650... Time elapsed: 0.818811 second(s)
# Processing batch 394 of 650... Time elapsed: 0.053737 second(s)
# Processing batch 395 of 650... Time elapsed: 0.845890 second(s)
# Processing batch 396 of 650... Time elapsed: 0.921273 second(s)
# Processing batch 397 of 650... Time elapsed: 0.166447 second(s)
# Processing batch 398 of 650... Time elapsed: 0.727468 second(s)
# Processing batch 399 of 650... Time elapsed: 0.561761 second(s)
# Processing batch 400 of 650... Time elapsed: 0.593396 second(s)
# Processing batch 401 of 650... Time elapsed: 0.373342 second(s)
# Processing batch 402 of 650... Time elapsed: 0.885385 second(s)
# Processing batch 403 of 650... Time elapsed: 0.017618 second(s)
# Processing batch 404 of 650... Time elapsed: 0.872890 second(s)
# Processing batch 405 of 650... Time elapsed: 0.919210 second(s)
# Processing batch 406 of 650... Time elapsed: 0.857561 second(s)
# Processing batch 407 of 650... Time elapsed: 0.878355 second(s)
# Processing batch 408 of 650... Time elapsed: 0.053073 second(s)
# Processing batch 409 of 650... Time elapsed: 0.816108 second(s)
# Processing batch 410 of 650... Time elapsed: 0.806630 second(s)
# Processing batch 411 of 650... Time elapsed: 0.785473 second(s)
# Processing batch 412 of 650... Time elapsed: 0.787717 second(s)
# Processing batch 413 of 650... Time elapsed: 0.076953 second(s)
# Processing batch 414 of 650... Time elapsed: 0.829495 second(s)
# Processing batch 415 of 650... Time elapsed: 0.498280 second(s)
# Processing batch 416 of 650... Time elapsed: 0.845943 second(s)
# Processing batch 417 of 650... Time elapsed: 0.796168 second(s)
# Processing batch 418 of 650... Time elapsed: 0.808783 second(s)
# Processing batch 419 of 650... Time elapsed: 0.295411 second(s)
# Processing batch 420 of 650... Time elapsed: 0.802802 second(s)
# Processing batch 421 of 650... Time elapsed: 0.357477 second(s)
# Processing batch 422 of 650... Time elapsed: 0.891004 second(s)
# Processing batch 423 of 650... Time elapsed: 0.901997 second(s)
# Processing batch 424 of 650... Time elapsed: 0.822343 second(s)
# Processing batch 425 of 650... Time elapsed: 0.866830 second(s)
# Processing batch 426 of 650... Time elapsed: 0.860971 second(s)
# Processing batch 427 of 650... Time elapsed: 0.853055 second(s)
# Processing batch 428 of 650... Time elapsed: 0.855529 second(s)
# Processing batch 429 of 650... Time elapsed: 0.828302 second(s)
# Processing batch 430 of 650... Time elapsed: 0.410022 second(s)
# Processing batch 431 of 650... Time elapsed: 0.826796 second(s)
# Processing batch 432 of 650... Time elapsed: 0.880900 second(s)
# Processing batch 433 of 650... Time elapsed: 0.866577 second(s)
# Processing batch 434 of 650... Time elapsed: 0.846041 second(s)
# Processing batch 435 of 650... Time elapsed: 0.819236 second(s)
# Processing batch 436 of 650... Time elapsed: 0.889682 second(s)
# Processing batch 437 of 650... Time elapsed: 0.287078 second(s)
# Processing batch 438 of 650... Time elapsed: 0.851690 second(s)
# Processing batch 439 of 650... Time elapsed: 0.890007 second(s)
# Processing batch 440 of 650... Time elapsed: 0.894839 second(s)
# Processing batch 441 of 650... Time elapsed: 0.853495 second(s)
# Processing batch 442 of 650... Time elapsed: 0.859098 second(s)
# Processing batch 443 of 650... Time elapsed: 0.900527 second(s)
# Processing batch 444 of 650... Time elapsed: 0.885689 second(s)
# Processing batch 445 of 650... Time elapsed: 0.911163 second(s)
# Processing batch 446 of 650... Time elapsed: 0.897291 second(s)
# Processing batch 447 of 650... Time elapsed: 0.848342 second(s)
# Processing batch 448 of 650... Time elapsed: 0.369170 second(s)
# Processing batch 449 of 650... Time elapsed: 0.677686 second(s)
# Processing batch 450 of 650... Time elapsed: 0.791739 second(s)
# Processing batch 451 of 650... Time elapsed: 0.770948 second(s)
# Processing batch 452 of 650... Time elapsed: 0.759732 second(s)
# Processing batch 453 of 650... Time elapsed: 0.740423 second(s)
# Processing batch 454 of 650... Time elapsed: 0.734146 second(s)
# Processing batch 455 of 650... Time elapsed: 0.764725 second(s)
# Processing batch 456 of 650... Time elapsed: 0.707800 second(s)
# Processing batch 457 of 650... Time elapsed: 0.850181 second(s)
# Processing batch 458 of 650... Time elapsed: 0.926198 second(s)
# Processing batch 459 of 650... Time elapsed: 0.838591 second(s)
# Processing batch 460 of 650... Time elapsed: 0.762246 second(s)
# Processing batch 461 of 650... Time elapsed: 0.834085 second(s)
# Processing batch 462 of 650... Time elapsed: 0.862678 second(s)
# Processing batch 463 of 650... Time elapsed: 0.772637 second(s)
# Processing batch 464 of 650... Time elapsed: 0.313517 second(s)
# Processing batch 465 of 650... Time elapsed: 0.868286 second(s)
# Processing batch 466 of 650... Time elapsed: 0.960966 second(s)
# Processing batch 467 of 650... Time elapsed: 0.826164 second(s)
# Processing batch 468 of 650... Time elapsed: 0.860810 second(s)
# Processing batch 469 of 650... Time elapsed: 0.867313 second(s)
# Processing batch 470 of 650... Time elapsed: 0.529737 second(s)
# Processing batch 471 of 650... Time elapsed: 0.764815 second(s)
# Processing batch 472 of 650... Time elapsed: 0.808571 second(s)
# Processing batch 473 of 650... Time elapsed: 0.822047 second(s)
# Processing batch 474 of 650... Time elapsed: 0.799743 second(s)
# Processing batch 475 of 650... Time elapsed: 0.788608 second(s)
# Processing batch 476 of 650... Time elapsed: 0.264220 second(s)
# Processing batch 477 of 650... Time elapsed: 0.795753 second(s)
# Processing batch 478 of 650... Time elapsed: 0.853683 second(s)
# Processing batch 479 of 650... Time elapsed: 0.812019 second(s)
# Processing batch 480 of 650... Time elapsed: 0.774286 second(s)
# Processing batch 481 of 650... Time elapsed: 0.690537 second(s)
# Processing batch 482 of 650... Time elapsed: 0.829052 second(s)
# Processing batch 483 of 650... Time elapsed: 0.888966 second(s)
# Processing batch 484 of 650... Time elapsed: 0.780955 second(s)
# Processing batch 485 of 650... Time elapsed: 0.330002 second(s)
# Processing batch 486 of 650... Time elapsed: 0.808994 second(s)
# Processing batch 487 of 650... Time elapsed: 0.833994 second(s)
# Processing batch 488 of 650... Time elapsed: 0.806551 second(s)
# Processing batch 489 of 650... Time elapsed: 0.738300 second(s)
# Processing batch 490 of 650... Time elapsed: 0.816551 second(s)
# Processing batch 491 of 650... Time elapsed: 0.231170 second(s)
# Processing batch 492 of 650... Time elapsed: 0.779160 second(s)
# Processing batch 493 of 650... Time elapsed: 0.731498 second(s)
# Processing batch 494 of 650... Time elapsed: 0.549912 second(s)
# Processing batch 495 of 650... Time elapsed: 0.805302 second(s)
# Processing batch 496 of 650... Time elapsed: 0.345083 second(s)
# Processing batch 497 of 650... Time elapsed: 0.805997 second(s)
# Processing batch 498 of 650... Time elapsed: 0.796002 second(s)
# Processing batch 499 of 650... Time elapsed: 0.297066 second(s)
# Processing batch 500 of 650... Time elapsed: 0.741026 second(s)
# Processing batch 501 of 650... Time elapsed: 0.832627 second(s)
# Processing batch 502 of 650... Time elapsed: 0.016594 second(s)
# Processing batch 503 of 650... Time elapsed: 0.791260 second(s)
# Processing batch 504 of 650... Time elapsed: 0.802630 second(s)
# Processing batch 505 of 650... Time elapsed: 0.882565 second(s)
# Processing batch 506 of 650... Time elapsed: 0.777594 second(s)
# Processing batch 507 of 650... Time elapsed: 0.777479 second(s)
# Processing batch 508 of 650... Time elapsed: 0.747945 second(s)
# Processing batch 509 of 650... Time elapsed: 0.755539 second(s)
# Processing batch 510 of 650... Time elapsed: 0.737442 second(s)
# Processing batch 511 of 650... Time elapsed: 0.765777 second(s)
# Processing batch 512 of 650... Time elapsed: 0.532024 second(s)
# Processing batch 513 of 650... Time elapsed: 0.851480 second(s)
# Processing batch 514 of 650... Time elapsed: 0.824432 second(s)
# Processing batch 515 of 650... Time elapsed: 0.080854 second(s)
# Processing batch 516 of 650... Time elapsed: 0.875506 second(s)
# Processing batch 517 of 650... Time elapsed: 0.865082 second(s)
# Processing batch 518 of 650... Time elapsed: 0.880211 second(s)
# Processing batch 519 of 650... Time elapsed: 0.339421 second(s)
# Processing batch 520 of 650... Time elapsed: 0.633813 second(s)
# Processing batch 521 of 650... Time elapsed: 0.723424 second(s)
# Processing batch 522 of 650... Time elapsed: 0.045824 second(s)
# Processing batch 523 of 650... Time elapsed: 0.240643 second(s)
# Processing batch 524 of 650... Time elapsed: 0.854344 second(s)
# Processing batch 525 of 650... Time elapsed: 0.376646 second(s)
# Processing batch 526 of 650... Time elapsed: 0.783992 second(s)
# Processing batch 527 of 650... Time elapsed: 0.768315 second(s)
# Processing batch 528 of 650... Time elapsed: 0.723528 second(s)
# Processing batch 529 of 650... Time elapsed: 0.756775 second(s)
# Processing batch 530 of 650... Time elapsed: 0.721281 second(s)
# Processing batch 531 of 650... Time elapsed: 0.711692 second(s)
# Processing batch 532 of 650... Time elapsed: 0.664210 second(s)
# Processing batch 533 of 650... Time elapsed: 0.711200 second(s)
# Processing batch 534 of 650... Time elapsed: 0.727058 second(s)
# Processing batch 535 of 650... Time elapsed: 0.809668 second(s)
# Processing batch 536 of 650... Time elapsed: 0.732651 second(s)
# Processing batch 537 of 650... Time elapsed: 0.762728 second(s)
# Processing batch 538 of 650... Time elapsed: 0.880517 second(s)
# Processing batch 539 of 650... Time elapsed: 0.810880 second(s)
# Processing batch 540 of 650... Time elapsed: 0.744460 second(s)
# Processing batch 541 of 650... Time elapsed: 0.698045 second(s)
# Processing batch 542 of 650... Time elapsed: 0.818339 second(s)
# Processing batch 543 of 650... Time elapsed: 0.716259 second(s)
# Processing batch 544 of 650... Time elapsed: 0.726390 second(s)
# Processing batch 545 of 650... Time elapsed: 0.748673 second(s)
# Processing batch 546 of 650... Time elapsed: 0.721856 second(s)
# Processing batch 547 of 650... Time elapsed: 0.686917 second(s)
# Processing batch 548 of 650... Time elapsed: 0.720990 second(s)
# Processing batch 549 of 650... Time elapsed: 0.741624 second(s)
# Processing batch 550 of 650... Time elapsed: 0.751067 second(s)
# Processing batch 551 of 650... Time elapsed: 0.732350 second(s)
# Processing batch 552 of 650... Time elapsed: 0.650594 second(s)
# Processing batch 553 of 650... Time elapsed: 0.334946 second(s)
# Processing batch 554 of 650... Time elapsed: 0.840668 second(s)
# Processing batch 555 of 650... Time elapsed: 0.835770 second(s)
# Processing batch 556 of 650... Time elapsed: 0.877046 second(s)
# Processing batch 557 of 650... Time elapsed: 0.818176 second(s)
# Processing batch 558 of 650... Time elapsed: 0.805403 second(s)
# Processing batch 559 of 650... Time elapsed: 0.958341 second(s)
# Processing batch 560 of 650... Time elapsed: 0.718826 second(s)
# Processing batch 561 of 650... Time elapsed: 0.869317 second(s)
# Processing batch 562 of 650... Time elapsed: 0.819095 second(s)
# Processing batch 563 of 650... Time elapsed: 0.817298 second(s)
# Processing batch 564 of 650... Time elapsed: 0.770970 second(s)
# Processing batch 565 of 650... Time elapsed: 0.775648 second(s)
# Processing batch 566 of 650... Time elapsed: 0.526574 second(s)
# Processing batch 567 of 650... Time elapsed: 0.801813 second(s)
# Processing batch 568 of 650... Time elapsed: 0.820636 second(s)
# Processing batch 569 of 650... Time elapsed: 0.911481 second(s)
# Processing batch 570 of 650... Time elapsed: 0.984496 second(s)
# Processing batch 571 of 650... Time elapsed: 0.440093 second(s)
# Processing batch 572 of 650... Time elapsed: 0.742831 second(s)
# Processing batch 573 of 650... Time elapsed: 0.849332 second(s)
# Processing batch 574 of 650... Time elapsed: 0.258867 second(s)
# Processing batch 575 of 650... Time elapsed: 0.875771 second(s)
# Processing batch 576 of 650... Time elapsed: 0.763936 second(s)
# Processing batch 577 of 650... Time elapsed: 0.870158 second(s)
# Processing batch 578 of 650... Time elapsed: 0.870789 second(s)
# Processing batch 579 of 650... Time elapsed: 0.767801 second(s)
# Processing batch 580 of 650... Time elapsed: 0.588631 second(s)
# Processing batch 581 of 650... Time elapsed: 0.672723 second(s)
# Processing batch 582 of 650... Time elapsed: 0.687626 second(s)
# Processing batch 583 of 650... Time elapsed: 0.667790 second(s)
# Processing batch 584 of 650... Time elapsed: 0.636509 second(s)
# Processing batch 585 of 650... Time elapsed: 0.719203 second(s)
# Processing batch 586 of 650... Time elapsed: 0.745239 second(s)
# Processing batch 587 of 650... Time elapsed: 0.683114 second(s)
# Processing batch 588 of 650... Time elapsed: 0.709886 second(s)
# Processing batch 589 of 650... Time elapsed: 0.717219 second(s)
# Processing batch 590 of 650... Time elapsed: 0.831017 second(s)
# Processing batch 591 of 650... Time elapsed: 0.737027 second(s)
# Processing batch 592 of 650... Time elapsed: 0.727685 second(s)
# Processing batch 593 of 650... Time elapsed: 0.697333 second(s)
# Processing batch 594 of 650... Time elapsed: 0.909578 second(s)
# Processing batch 595 of 650... Time elapsed: 0.923057 second(s)
# Processing batch 596 of 650... Time elapsed: 0.607239 second(s)
# Processing batch 597 of 650... Time elapsed: 0.859655 second(s)
# Processing batch 598 of 650... Time elapsed: 0.858363 second(s)
# Processing batch 599 of 650... Time elapsed: 0.794115 second(s)
# Processing batch 600 of 650... Time elapsed: 0.316933 second(s)
# Processing batch 601 of 650... Time elapsed: 1.029860 second(s)
# Processing batch 602 of 650... Time elapsed: 0.459585 second(s)
# Processing batch 603 of 650... Time elapsed: 0.691651 second(s)
# Processing batch 604 of 650... Time elapsed: 0.145516 second(s)
# Processing batch 605 of 650... Time elapsed: 0.981365 second(s)
# Processing batch 606 of 650... Time elapsed: 0.883419 second(s)
# Processing batch 607 of 650... Time elapsed: 0.954945 second(s)
# Processing batch 608 of 650... Time elapsed: 1.057308 second(s)
# Processing batch 609 of 650... Time elapsed: 1.061285 second(s)
# Processing batch 610 of 650... Time elapsed: 0.996323 second(s)
# Processing batch 611 of 650... Time elapsed: 0.782376 second(s)
# Processing batch 612 of 650... Time elapsed: 0.925529 second(s)
# Processing batch 613 of 650... Time elapsed: 0.476612 second(s)
# Processing batch 614 of 650... Time elapsed: 0.774982 second(s)
# Processing batch 615 of 650... Time elapsed: 0.745248 second(s)
# Processing batch 616 of 650... Time elapsed: 0.739709 second(s)
# Processing batch 617 of 650... Time elapsed: 0.680804 second(s)
# Processing batch 618 of 650... Time elapsed: 0.721207 second(s)
# Processing batch 619 of 650... Time elapsed: 0.655987 second(s)
# Processing batch 620 of 650... Time elapsed: 0.819080 second(s)
# Processing batch 621 of 650... Time elapsed: 0.806169 second(s)
# Processing batch 622 of 650... Time elapsed: 0.882010 second(s)
# Processing batch 623 of 650... Time elapsed: 0.971922 second(s)
# Processing batch 624 of 650... Time elapsed: 0.813751 second(s)
# Processing batch 625 of 650... Time elapsed: 1.027625 second(s)
# Processing batch 626 of 650... Time elapsed: 0.896444 second(s)
# Processing batch 627 of 650... Time elapsed: 0.854137 second(s)
# Processing batch 628 of 650... Time elapsed: 0.865686 second(s)
# Processing batch 629 of 650... Time elapsed: 0.783409 second(s)
# Processing batch 630 of 650... Time elapsed: 0.572554 second(s)
# Processing batch 631 of 650... Time elapsed: 0.209482 second(s)
# Processing batch 632 of 650... Time elapsed: 0.665816 second(s)
# Processing batch 633 of 650... Time elapsed: 0.525041 second(s)
# Processing batch 634 of 650... Time elapsed: 0.780280 second(s)
# Processing batch 635 of 650... Time elapsed: 0.779376 second(s)
# Processing batch 636 of 650... Time elapsed: 0.843181 second(s)
# Processing batch 637 of 650... Time elapsed: 0.868374 second(s)
# Processing batch 638 of 650... Time elapsed: 0.726951 second(s)
# Processing batch 639 of 650... Time elapsed: 0.983836 second(s)
# Processing batch 640 of 650... Time elapsed: 0.921156 second(s)
# Processing batch 641 of 650... Time elapsed: 0.831828 second(s)
# Processing batch 642 of 650... Time elapsed: 0.058003 second(s)
# Processing batch 643 of 650... Time elapsed: 0.900669 second(s)
# Processing batch 644 of 650... Time elapsed: 0.816159 second(s)
# Processing batch 645 of 650... Time elapsed: 0.011221 second(s)
# Processing batch 646 of 650... Time elapsed: 0.714879 second(s)
# Processing batch 647 of 650... Time elapsed: 0.776905 second(s)
# Processing batch 648 of 650... Time elapsed: 0.764509 second(s)
# Processing batch 649 of 650... Time elapsed: 0.773018 second(s)
# Processing batch 650 of 650... Time elapsed: 0.077833 second(s)
# Total time elapsed: 519.114876 second(s)

# %%
import numpy as np

# convert histogram into two lists `lemmas_unsorted` and `counts_unsorted`
# where the i-th lemma in `lemmas_unsorted` has raw counts given by
# `counts_unsorted[i]`
lemmas_unsorted = []
counts_unsorted = []
for lemma, count in histogram.items():
    lemmas_unsorted.append(lemma)
    counts_unsorted.append(count)
counts_unsorted = np.array(counts_unsorted)  # to allow for fancy numpy indexing

# compute the indices that would sort the list `counts_unsorted` in
# decreasing order (which is why there's a "::-1")
sort_indices = np.argsort(counts_unsorted)[::-1]
sorted_counts = counts_unsorted[sort_indices]  # actually for later problem subparts

print('Rank'.ljust(5), 'Lemma'.ljust(10), 'Raw Count')
for rank, idx in enumerate(sort_indices[:50]):
    print(str(rank + 1).ljust(5), lemmas_unsorted[idx].ljust(10), counts_unsorted[idx])
# Out:
# Rank  Lemma      Raw Count
# 1     the        702390
# 2     be         437509
# 3     and        435352
# 4     of         386329
# 5     to         324392
# 6     a          233427
# 7     in         204235
# 8     that       158927
# 9     have       158459
# 10    not        112469
# 11    with       101218
# 12    for        95317
# 13    as         90680
# 14    but        75564
# 15    at         64965
# 16    do         64574
# 17    on         62831
# 18    by         61964
# 19    this       61232
# 20    which      58845
# 21    all        58703
# 22    say        58356
# 23    from       50092
# 24    so         47992
# 25    or         47799
# 26    will       42617
# 27    one        41005
# 28    man        39614
# 29    no         38457
# 30    what       37763
# 31    there      37175
# 32    if         34885
# 33    go         34012
# 34    when       33581
# 35    an         32542
# 36    come       32418
# 37    would      32118
# 38    see        31994
# 39    who        30899
# 40    make       30434
# 41    then       27335
# 42    out        26869
# 43    may        25919
# 44    know       25504
# 45    up         25346
# 46    more       25137
# 47    take       23940
# 48    other      23666
# 49    now        23450
# 50    shall      22829

# %% [markdown]
# **(c) [10 pts]** Visualize the frequency table by plotting a **raw scatter plot** (put frequency as the y-axis and rank as the x-axis), and a **log-log plot** (use logarithmic scales on both the x- and y- axes). Note that this should be for all words and not only the top 50. As before, for the ranks, do not worry about ties, i.e., break ties arbitrarily.

# %%
# Raw scatter plot
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')  # makes prettier plots

# Using Solution from part (b):
plt.scatter(np.array(range(len(sort_indices))) + 1, sorted_counts)
plt.xlabel('Rank')
plt.ylabel('Raw Count')
# Out:
# Text(0, 0.5, 'Raw Count')

# %%
# Log-log plot
plt.scatter(np.array(range(len(sort_indices))) + 1, sorted_counts)
plt.xlabel('Rank')
plt.ylabel('Raw Count')
axis = plt.gca()  # gets the current axis
axis.set_xscale('log')
axis.set_yscale('log')

# %% [markdown]
# **(d) [10 pts across subparts]** Let's now try to make sense of the very last plot in part **(c)**. Zipf's law states that term frequency is governed by a power law, i.e. the relationship between term frequency and rank can be approximated by $f(r) = cr^{-1}$, where $f(r)$ is the frequency of the term at rank $r$, $r$ is the rank of a term, and $c$ is a constant that is approximately 0.1*(corpus size) for English.
#
# Please answer the following questions:
#
# **Subpart i [3 pts].** What do you observe in the log-log plot above? Is this consist with the power law?

# %% [markdown]
# Your text answer (for this question, your answer is *not* code):
#
# **Answer:** The log-log plot of frequency and rank roughly corresponds to a line with a negative slope (at least up a rank of $\sim10^{3.5}$, after which the plot starts curving downward). Where the plot corresponds to a line, it is consistent with a power law, as the power law suggests $\log(f(r)) = -c\log(r)$, which is a line with slope of $-c$.

# %% [markdown]
# **Subpart ii [4 pts].** Think of the corpus as a (large) unigram bag of words. Following the analogy from lecture, imagine drawing a single word from this big bag (note that we are assuming that we've lemmatized the words and also filtered out non-alphabetic words; thus what remains in the bag are actually alphabetic lemmas). What is the probability of drawing one of the 4 most frequent alphabetic lemmas? What is the probability of drawing one of the 50 most frequent alphabetic lemmas? Answer these two questions using code rather than just entering in the final answers as numbers.

# %%
print('Probability of drawing one of the 4 most frequent alphabetic lemmas: ')
print(sorted_counts[:4].sum() / sorted_counts.sum())

print('Probability of drawing one of the 50 most frequent alphabetic lemmas: ')
print(sorted_counts[:50].sum() / sorted_counts.sum())
# Out:
# Probability of drawing one of the 4 most frequent alphabetic lemmas:
# 0.1815856768023414
# Probability of drawing one of the 50 most frequent alphabetic lemmas:
# 0.45666541757355517

# %% [markdown]
# **Subpart iii [4 pts].** What proportion of the alphabetic lemmas occur only once? What proportion of the alphabetic lemmas occur fewer than 10 times?

# %%
print("Occur only once: ")
print((sorted_counts == 1).sum() / len(sorted_counts))

print("Occur fewer than 10 times: ")
print((sorted_counts < 10).sum() / len(sorted_counts))
# Out:
# Occur only once:
# 0.44600286830165875
# Occur fewer than 10 times:
# 0.7814859245762941

# %% [markdown]
# ### [Problem 2] Entity Recognition and Pointwise Mutual Information (PMI) [50 pts]
# By using the entity recognition system in `spaCy`, let's identify named entities from newspaper articles. You'll be using Reuters corpus which contains more than ten thousand newspaper articles. To run the code below, you need to download the Reuters dataset. To do so, in a terminal/command line (recall that you can open a terminal from Jupyter's webpage that shows all the files, which by default is [http://localhost:8888/tree](http://localhost:8888/tree)), start up Python and enter:
#
# ```python
# import nltk
# nltk.download('reuters')
# ```
#
# Then proceed to the problem subparts below.
#
# Note that in this problem you will need named entity recognition but not grammatical parsing. Hence, you will want to instantiate the nlp object by calling:
#
# ```python
# nlp = spacy.load('en_core_web_sm', disable=['parser'])
# ```

# %% [markdown]
# **(a) [15 pts]** Draw a bar chart in which one of the axes shows entity labels and the other shows the frequency of the corresponding label. Use the variables `reuters_nlp` and `label_counter` provided in the code below.

# %%
import matplotlib.pyplot as plt
from collections import Counter
from nltk.corpus import reuters
import re
import spacy
nlp = spacy.load('en_core_web_sm', disable=['parser'])
reuters_fileids = reuters.fileids()  # hint: when first debugging, consider looking at just the first few
reuters_nlp = [nlp(re.sub('\s+',' ', reuters.raw(i)).strip()) for i in reuters_fileids]
label_counter = Counter()

for article in reuters_nlp:
    label_list = [ent.label_ for ent in article.ents]
    label_counter.update(label_list)
labels = [item[0] for item in label_counter.items()]
label_occurrences = [item[1] for item in label_counter.items()]
y_pos = range(len(labels))
plt.barh(y_pos, label_occurrences, align='center', alpha=0.5)
plt.yticks(y_pos, labels)
# Out:
# ([<matplotlib.axis.YTick at 0x7f9df1aa8f50>,
#   <matplotlib.axis.YTick at 0x7f9df1aa8450>,
#   <matplotlib.axis.YTick at 0x7f9df1a9f9d0>,
#   <matplotlib.axis.YTick at 0x7f9df1b13fd0>,
#   <matplotlib.axis.YTick at 0x7f9df1b235d0>,
#   <matplotlib.axis.YTick at 0x7f9df1b23b50>,
#   <matplotlib.axis.YTick at 0x7f9df189a050>,
#   <matplotlib.axis.YTick at 0x7f9df189a610>,
#   <matplotlib.axis.YTick at 0x7f9df189ab50>,
#   <matplotlib.axis.YTick at 0x7f9df189a690>,
#   <matplotlib.axis.YTick at 0x7f9df1b23650>,
#   <matplotlib.axis.YTick at 0x7f9df18a5210>,
#   <matplotlib.axis.YTick at 0x7f9df18a5750>,
#   <matplotlib.axis.YTick at 0x7f9df18a5c90>,
#   <matplotlib.axis.YTick at 0x7f9df18ac210>,
#   <matplotlib.axis.YTick at 0x7f9df18ac750>,
#   <matplotlib.axis.YTick at 0x7f9df18acc90>,
#   <matplotlib.axis.YTick at 0x7f9df18b4210>],
#  [Text(0, 0, 'ORG'),
#   Text(0, 1, 'GPE'),
#   Text(0, 2, 'LOC'),
#   Text(0, 3, 'PERSON'),
#   Text(0, 4, 'NORP'),
#   Text(0, 5, 'CARDINAL'),
#   Text(0, 6, 'DATE'),
#   Text(0, 7, 'MONEY'),
#   Text(0, 8, 'ORDINAL'),
#   Text(0, 9, 'QUANTITY'),
#   Text(0, 10, 'LAW'),
#   Text(0, 11, 'PRODUCT'),
#   Text(0, 12, 'EVENT'),
#   Text(0, 13, 'TIME'),
#   Text(0, 14, 'PERCENT'),
#   Text(0, 15, 'FAC'),
#   Text(0, 16, 'WORK_OF_ART'),
#   Text(0, 17, 'LANGUAGE')])

# %% [markdown]
# **(b) [15 pts]** Now list the top 10 most frequently occurring entities (entity text and the number of occurence) with label `ORG` (organization). Separately list the top 10 most frequently occurring entities with label `GPE` (geopolitical entity such as countries, cities, states) respectively. **In both cases, please convert the entity names to lowercase first before computing the top 10.**
#
# Here, when counting the (raw count) frequency, we need to count how many articles have an entity with the desired property. For every article, we add 1 if the article has the entity and 0 otherwise.

# %%
common_org = Counter()
common_gpe = Counter()

for article in reuters_nlp:
    org_list = set([ent.lemma_.lower() for ent in article.ents if ent.label_ == u"ORG"])
    gpe_list = set([ent.lemma_.lower() for ent in article.ents if ent.label_ == u"GPE"])
    
    # for counting total number of times entities occur and not just whether
    # they occured in the article or not:
    # org_list = [ent.lemma_ for ent in article.ents if ent.label_ == u"ORG"]
    # gpe_list = [ent.lemma_ for ent in article.ents if ent.label_ == u"GPE"]
    common_org.update(org_list)
    common_gpe.update(gpe_list)

print('Most frequently occurring organizations:')
print("\n".join(["  %s: %d" % (entity, count) for entity, count in common_org.most_common(10)]))

print()

print('Most frequently occurring locations:')
print("\n".join(["  %s: %d" % (entity, count) for entity, count in common_gpe.most_common(10)]))
# Out:
# Most frequently occurring organizations:
#   note: 431
#   reuters: 430
#   the securities and exchange commission: 248
#   >: 245
#   ec: 239
#   fed: 223
#   usda: 220
#   net shr: 188
#   the u.s. agriculture department: 165
#   treasury: 159
#
# Most frequently occurring locations:
#   u.s.: 1666
#   japan: 565
#   the united states: 380
#   u.k.: 307
#   new york: 266
#   washington: 239
#   canada: 238
#   west germany: 233
#   london: 211
#   brazil: 188

# %% [markdown]
# **(c) [20 pts]** Give the top 50 `GPE` (countries, cities, states) entities that have the highest Pointwise Mutual Information (PMI) values with regard to the `ORG` (organization) entity **'opec'** (your list of this top 50 should be ranked in decreasing PMI value). Did you find any unexpected results? If so, why do you think it happened? If you found some of the results to be unsurprisingly, how come? **Just like in the previous part, please convert entity names to lowercase in your analysis.**
#
# Hint 1: As in lecture, when computing PMI, we will compute probabilities by counting the number of documents where entities occur or co-occur.  For example, $P('opec') = \frac{number \ \ of \ \ documents \ \ containing \ \ 'opec'}{number \ \ of \ \ documents}$.
#
# Hint 2: To compute this ranking, you do not have to compute the full PMI equation.

# %% [markdown]
# **Solution note:** For a specific `GPE` entity $x$, we have
#
# $$\text{PMI}(\text{opec}, x)
# = \log\frac{P(\text{opec}, x)}{P(\text{opec})P(x)}
# = \log\frac{\frac{\text{# articles opec and }x\text{ are both in}}{\text{total # articles}}}{P(\text{opec})\frac{\text{# articles }x\text{ is in}}{\text{total # articles}}}
# = \log\frac{\text{# articles opec and }x\text{ are both in}}{P(\text{opec})(\text{# articles }x\text{ is in})}\,.$$
#
# For different values of $x$, $P(\text{opec})$ is a constant! This means that in terms of ordering the different $x$'s by PMI, we do not need to compute $P(\text{opec})$. Moreover, whether we take the logarithm or not also doesn't affect the ordering of the $x$'s according to PMI. Thus, for each $x$, it suffices to compute the fraction
#
# $$\frac{\text{# articles opec and }x\text{ are both in}}{\text{# articles }x\text{ is in}}\,.$$
#
# By sorting the $x$'s according to this fraction, we get the same ordering as if we sorted the $x$'s according to PMI.

# %%
co_occurrence_counts = Counter()
gpe_counts = Counter()

for article in reuters_nlp:
    article_gpe = set([ent.lemma_.lower() for ent in article.ents if ent.label_ == u'GPE'])
    article_org = set([ent.lemma_.lower() for ent in article.ents if ent.label_ == u'ORG'])
    gpe_counts.update(article_gpe)
    if 'opec' in article_org:
        co_occurrence_counts.update(article_gpe)
        
part_of_pmi_equation = dict()
for gpe, co_occurrence_count in co_occurrence_counts.items():
    part_of_pmi_equation[gpe] = co_occurrence_count / gpe_counts[gpe]
    
print('Rank'.ljust(5), 'Location'.ljust(30), 'Co-occurrence Count'.ljust(20), 'Occurrence Count'.ljust(20))

for i, w in enumerate(sorted(part_of_pmi_equation,
                             key=part_of_pmi_equation.get,
                             reverse=True)[:50]):
    print(str(i+1).ljust(5), w.ljust(30), str(co_occurrence_counts[w]).ljust(20), str(gpe_counts[w]).ljust(20))
# Out:
# Rank  Location                       Co-occurrence Count  Occurrence Count
# 1     minas                          1                    1
# 2     brent                          3                    3
# 3     aramco                         1                    1
# 4     petromin                       1                    1
# 5     emirates                       1                    1
# 6     la                             1                    1
# 7     bethesda                       1                    1
# 8     gabon                          2                    2
# 9     wellemeyer                     1                    1
# 10    opecna                         1                    1
# 11    aguarico                       1                    1
# 12    ecaudor                        1                    1
# 13    ju'aymah                       1                    1
# 14    tripoli                        2                    2
# 15    doha                           1                    1
# 16    presidency                     1                    1
# 17    non - opec mexico              1                    1
# 18    maracaibo                      2                    2
# 19    guayaquil                      2                    2
# 20    vienna                         17                   20
# 21    riyadh                         4                    5
# 22    balao                          10                   14
# 23    saudi arabia 's                11                   16
# 24    dubai                          4                    6
# 25    petronas                       2                    3
# 26    quito                          4                    6
# 27    libya                          6                    10
# 28    qatar                          15                   26
# 29    nigeria                        10                   18
# 30    caracas                        5                    9
# 31    alexandria                     1                    2
# 32    statfjord                      1                    2
# 33    3.7500/03                      1                    2
# 34    lagos                          1                    2
# 35    osprey                         1                    2
# 36    ecuador                        25                   57
# 37    saudi arabia                   28                   65
# 38    kuwait                         27                   66
# 39    pertamina                      2                    5
# 40    jamaica                        2                    5
# 41    venezuela                      17                   44
# 42    the united arab emirates       11                   29
# 43    jakarta                        4                    12
# 44    uae                            2                    7
# 45    san antonio                    1                    4
# 46    the united states '            1                    5
# 47    dublin                         1                    5
# 48    iceland                        1                    5
# 49    kingdom                        1                    5
# 50    iraq                           14                   75

# %% [markdown]
# Your text answer (for this question, your answer is *not* code):
#
# **Answer:** Entities such as 'dubai' and 'qatar' were expected to have very high ranks since they are directly related to OPEC. However, in the result, somewhat meaningless entities have highest PMI values. There are various reasons for why this happens. Perhaps the most important is that PMI naturally gives high scores to rare words (words with very low occurrences; notice how in the above output, the highest ranked words all have occurrence counts that are either 1 or close to 1). Two other reasons for why some meaningless entities might have high PMI scores: the entity recognition labeling of spaCy is not perfect, and the number of documents (here, newspaper articles) might have been too small.
